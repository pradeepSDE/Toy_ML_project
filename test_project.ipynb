# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
dfm= df.iloc[:,1:]

# %%
dfm.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'])

# %%
x = dfm.iloc[:,0:2]
y= dfm.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test  = train_test_split(x,y,test_size = 0.1)

# %%
x_train.head()
# Out:
#     cgpa     iq
# 54   6.4  141.0
# 84   5.7  169.0
# 74   6.7  154.0
# 98   6.3  103.0
# 86   5.1  128.0

# %%
x_train
# Out:
#     cgpa     iq
# 54   6.4  141.0
# 84   5.7  169.0
# 74   6.7  154.0
# 98   6.3  103.0
# 86   5.1  128.0
# ..   ...    ...
# 4    5.8  142.0
# 20   6.6  120.0
# 17   3.3  183.0
# 90   7.3   86.0
# 76   4.9  155.0
#
# [90 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.55605314, -0.48077765],
#        [-0.73257795, -0.40300056],
#        [ 2.18008136, -0.14374359],
#        [-1.87998919, -0.42892626],
#        [ 0.6796205 , -0.35114916],
#        [ 1.12093252, -1.95854239],
#        [-0.73257795,  2.55252892],
#        [ 0.15004609, -0.32522347],
#        [ 0.85614531,  1.90438649],
#        [-0.02647872, -0.0400408 ],
#        [ 0.06178368,  0.16736478],
#        [-0.99736515, -0.14374359],
#        [ 0.94440771, -2.01039378],
#        [-0.20300353,  1.04883848],
#        [ 0.06178368,  0.78958151],
#        [-0.55605314,  0.34884466],
#        [ 1.20919492,  0.16736478],
#        [-0.29126593,  0.16736478],
#        [-0.90910275, -0.19559498],
#        [-0.90910275, -1.62150833],
#        [ 0.06178368, -0.58448044],
#        [ 0.5030957 ,  0.32291896],
#        [-0.82084035,  1.30809545],
#        [-0.29126593,  0.37477036],
#        [ 1.82703174,  1.04883848],
#        [-2.2330388 ,  2.78586019],
#        [ 0.41483329,  0.8932843 ],
#        [-0.02647872,  0.60810163],
#        [ 0.41483329, -0.9215145 ],
#        [ 0.94440771,  0.65995302],
#        [-1.08562756,  0.40069605],
#        [-1.17388996, -0.11781789],
#        [ 1.56224453, -0.29929777],
#        [-0.99736515,  0.21921617],
#        [-0.73257795,  0.16736478],
#        [ 2.00355655,  1.10068988],
#        [-0.99736515,  1.8266094 ],
#        [ 1.12093252, -0.24744638],
#        [ 0.41483329,  0.11551338],
#        [-1.79172678, -1.31039996],
#        [ 1.29745733,  0.11551338],
#        [-0.99736515,  0.65995302],
#        [-1.08562756,  1.12661557],
#        [ 0.76788291, -0.76596032],
#        [ 0.41483329, -2.29557645],
#        [-2.4095636 ,  1.48957533],
#        [ 0.5913581 ,  1.46364964],
#        [ 0.5913581 ,  0.73773012],
#        [ 0.06178368, -1.56965693],
#        [ 0.23830849,  0.06366199],
#        [-0.64431554, -0.29929777],
#        [-0.99736515,  0.76365581],
#        [-0.02647872, -0.61040614],
#        [-0.64431554, -0.11781789],
#        [-1.52693957,  1.93031219],
#        [ 0.5030957 , -0.14374359],
#        [ 0.6796205 , -0.0659665 ],
#        [ 0.23830849, -0.58448044],
#        [-0.73257795, -0.9215145 ],
#        [ 1.29745733, -1.67335972],
#        [-1.08562756, -0.35114916],
#        [-0.11474112, -0.50670335],
#        [ 0.6796205 , -0.9215145 ],
#        [-0.02647872, -2.08817087],
#        [ 1.82703174,  0.60810163],
#        [-1.26215236,  0.53032454],
#        [ 0.76788291,  0.32291896],
#        [ 1.38571973, -0.9474402 ],
#        [ 1.12093252, -1.02521729],
#        [-0.99736515, -1.67335972],
#        [-0.55605314,  0.24514187],
#        [-0.82084035, -1.54373123],
#        [ 1.73876934, -1.20669717],
#        [-0.02647872, -1.54373123],
#        [-0.20300353,  0.42662175],
#        [ 1.12093252,  0.29699326],
#        [ 1.38571973,  0.06366199],
#        [ 0.85614531,  0.34884466],
#        [-1.17388996, -0.99929159],
#        [-0.55605314, -0.29929777],
#        [ 0.76788291,  0.34884466],
#        [ 0.85614531, -0.35114916],
#        [ 0.32657089,  0.40069605],
#        [ 0.32657089, -0.24744638],
#        [ 0.85614531,  1.28216976],
#        [-1.08562756,  0.97106139],
#        [ 0.23830849,  0.03773629],
#        [-0.29126593,  0.45254745],
#        [-1.43867717,  0.60810163],
#        [-0.82084035,  0.06366199]])

# %%
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[-1.40426824, -2.01060277],
#        [ 1.37439019,  0.84916466],
#        [ 0.11951219, -1.04912924],
#        [-1.76280481, -0.58071906],
#        [-1.13536581, -1.76407109],
#        [-0.6871951 ,  0.92312416],
#        [ 0.74695119,  0.43006081],
#        [ 0.92621948, -1.46823309],
#        [-0.23902438,  1.1203495 ],
#        [-0.86646338, -0.80259756]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_x = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,pred_x)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
